# %%
#Useful libraries
from bs4 import BeautifulSoup as bs
from urllib.request import Request, urlopen
from urllib.parse import urlparse
from tqdm import tqdm
import requests
import re
import os
import time
import dateutil

# %% [markdown]
# # 1. Data Collection

# %% [markdown]
# ## 1.1 Get the list of places

# %% [markdown]
# ### Chunk 1 [1-200]

# %%
with open('urls_1.txt', 'w') as f:
#next step is to iterate this process over the 400 pages
  for i in tqdm(range(1,201)):
    r = "https://www.atlasobscura.com/places?page="+str(i)+"&sort=likes_count"
    #response = requests.get(r, headers = {'User-agent': 'your bot 0.1'})
    response = requests.get(r)
    soup = bs(response.text)

    for link in soup.find_all('a', class_='content-card content-card-place'):
        #urls.append(link.get('href')))
        f.write(link.get('href')+'\n')

f.close
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [06:57<00:00,  2.09s/it]
# <function TextIOWrapper.close()>

# %% [markdown]
# ### Chunk 2 [201-400]

# %%
with open('urls_2.txt', 'w') as f:
#next step is to iterate this process over the 400 pages
  for i in tqdm(range(201,401)):
    r = "https://www.atlasobscura.com/places?page="+str(i)+"&sort=likes_count"
    #response = requests.get(r, headers = {'User-agent': 'your bot 0.1'})
    response = requests.get(r)
    soup = bs(response.text)

    for link in soup.find_all('a', class_='content-card content-card-place'):
        #urls.append(link.get('href')))
        f.write(link.get('href')+'\n')

f.close
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 200/200 [08:57<00:00,  2.69s/it]
# <function TextIOWrapper.close()>

# %%
#!cat urls_1.txt urls_2.txt > urls.txt
#!rm urls_1.txt
#!rm urls_2.txt

# %% [markdown]
# ### Merging the files

# %%
data = data2 = ""
  
# Reading data from file1
with open('urls_1.txt') as fp:
    data = fp.read()

# Reading data from file2
with open('urls_2.txt') as fp:
    data2 = fp.read()

#Merging 2 files
#To add the data of file2 from next line

data += "\n"
data += data2
  
with open ('urls.txt', 'w') as fp:
    fp.write(data)

# %% [markdown]
# ## 1.2 Crawl places

# %%
#import urllib.request as r
#page = r.urlopen('https://google.com')
#print(page.read().decode('utf8'))

# %%
#For one place
r2 = requests.get("https://www.atlasobscura.com/places/highgate-cemetery")

#convert to a bs object
soup2 = bs(r2.content)

#print out HTML
contents = soup2.prettify()
print(contents)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="reload" name="turbo-visit-control"/>
#   <script src="https://cdn.cookielaw.org/consent/c7042f21-9a02-4cf6-ad42-3e1f237e2b50/OtAutoBlock.js" type="text/javascript">
#   </script>
#   <script charset="UTF-8" data-domain-script="c7042f21-9a02-4cf6-ad42-3e1f237e2b50" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function OptanonWrapper() { }
#   </script>
#   <link as="font" crossorigin="" href="https://fonts.atlasobscura.com/2/Platform-Regular-Web.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://fonts.atlasobscura.com/2/Platform-Medium-Web.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="https://fonts.atlasobscura.com/2/FreigTexProBookWeb.woff2" rel="preload" type="font/woff2"/>
# ...

# %%
#place address
address = soup2.find(class_="DDPageSiderail__address").get_text().strip()
print(address)
# Out:
# Swain's Lane, HighgateLondon, England, N6United Kingdom

# %%
type(address)

#questo va bene perchè è una stringa
# Out:
# str

# %%
#place altitude and longitude
#da convertire in float, come fare??
alt_and_long_str = soup2.find(class_="DDPageSiderail__coordinates js-copy-coordinates").getText().strip()
alt_and_long = float(alt_and_long_str)
print(alt_and_long)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22600/842734834.py in <module>
#       2 #da convertire in float, come fare??
#       3 alt_and_long_str = soup2.find(class_="DDPageSiderail__coordinates js-copy-coordinates").getText().strip()
# ----> 4 alt_and_long = float(alt_and_long_str)
#       5 print(alt_and_long)
#
# ValueError: could not convert string to float: '51.5675, -0.1483'

# %%
type(alt_and_long)
# Out:
# str

# %%
#username of the post editors 
#eliminare gli spazi
#editors = soup2.find(class_="ugc-editors").getText().strip()
#print(editors)

# %%
#type(editors)

# %%
from datetime import datetime
from dateutil import parser

# %%
#Post publishing date
#da trasformare in datetime object, non capisco in che formato è la data
post_pub_date_str = soup2.find(class_="DDPContributor__name").getText().strip()
post_pub_date = datetime.strptime(post_pub_date_str, '%B%d%Y')
print(post_pub_date)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22600/4007768547.py in <module>
#       2 #da trasformare in datetime object, non capisco in che formato è la data
#       3 post_pub_date_str = soup2.find(class_="DDPContributor__name").getText().strip()
# ----> 4 post_pub_date = datetime.strptime(post_pub_date_str, '%B%d%Y')
#       5 print(post_pub_date)
#
# C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.2288.0_x64__qbz5n2kfra8p0\lib\_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ...

# %%
type(post_pub_date_str)
# Out:
# str

# %%
#The names of the lists that the place was included in
#place_lists = []
#place_lists.append(soup2.find_all('div', class_="")[0].getText().strip())


#place_lists

# %%
#p_l = soup2.find_all('h3', {'class' : 'Card__heading --content-card-v2-title js-title-content'})[0]
#p_l
